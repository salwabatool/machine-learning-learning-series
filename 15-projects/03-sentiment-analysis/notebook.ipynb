# %% [markdown]
# # Project: Sentiment Analysis
#
# > Part of the **Machine Learning Learning Series**

# %% [markdown]
# ## Project Overview
# **Goal**: Classify movie reviews as positive or negative.
#
# **Skills demonstrated**: NLP pipeline, TF-IDF, text classification.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import fetch_20newsgroups
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import MultinomialNB
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix
import seaborn as sns
import warnings; warnings.filterwarnings('ignore')

np.random.seed(42)
positives = [
    'This movie was absolutely fantastic and amazing',
    'Great performance and wonderful storyline',
    'I loved every minute of this film',
    'Brilliant direction and outstanding acting',
    'The best movie I have seen this year'
] * 100
negatives = [
    'Terrible movie completely waste of time',
    'Boring and predictable awful film',
    'The worst acting I have ever seen',
    'Disappointing and poorly made movie',
    'Horrible script and bad direction'
] * 100

texts = positives + negatives
labels = [1]*500 + [0]*500
df = pd.DataFrame({'text': texts, 'label': labels}).sample(frac=1, random_state=42)
print(f'Dataset: {len(df)} reviews')

# %% [markdown]
# ## Model Pipeline

# %%
X_train, X_test, y_train, y_test = train_test_split(df['text'], df['label'], test_size=0.2, random_state=42)

for name, clf in [('Naive Bayes', MultinomialNB()), ('Logistic Regression', LogisticRegression(max_iter=1000))]:
    pipe = Pipeline([('tfidf', TfidfVectorizer(ngram_range=(1,2), max_features=5000)), ('clf', clf)])
    pipe.fit(X_train, y_train)
    y_pred = pipe.predict(X_test)
    print(f'\n{name}: {accuracy_score(y_test, y_pred):.4f}')
    print(classification_report(y_test, y_pred, target_names=['Negative','Positive']))
